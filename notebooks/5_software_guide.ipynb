# %% [markdown]
# # Software guide
#
# ## Caching

# %%
# allows us to have visibility on our package without installing it in editing mode
import sys;
if ".." not in sys.path: sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt

# %%
from monaqa2.data.runtime import phase_gap_factor

phase_gap_factor.build_cache(
    axes=(np.logspace(-300, 0, 4096),),
    log_axes=(0,),
    log_output=True,
)
